# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.8.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-6.8.0-py3-none-any.whl (332 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader

reader = PdfReader("data/code_penal_togo.pdf")

print(len(reader.pages))
# Out:
# 256

# %%
from pypdf import PdfReader

reader = PdfReader("data/code_penal_togo.pdf")

text = ""

for page in reader.pages:
    text += page.extract_text()

print(text[:1000])
# Out:
# ASSEMBLEE NATIONALE     REPUBLIQUE  TOGOLAISE
#   ---------------  Travail-Liberté-Patrie
# SECRETARIAT GENERAL                 ------------
#   ---------------
# Direction des Services Législatifs
#   ---------------
# Division des Séances et Huissiers
#   ---------------
# Constitution du 14 Octobre 1992
# Cinquième Législature
#   ---------------
# Année 2015
# Séance plénière du 02/11/2015
# LOI N° 2015-10 du 24
# novembre 2015
# PORTANT NOUVEAU
# CODE PENAL1
# TITRE I : DISPOSITIONS GENERALES
# Chapitre I : De l’infraction
# Section 1 : De la loi pénale
# Article premier : Les infractions pénales sont classées, suivant leur gravité, en crimes, délits
# et contraventions.
# 1) les crimes sont punis de peines criminelles;
# 2) les délits sont punis de peines correctionnelles;
# 3) les contraventions sont punies de peines de police.
# Article 2 : La loi détermine les crimes et les délits et fixe les peines applicables à leurs
# auteurs.
# Le règlement détermine les contraventions et fixe, dans les limites et selon les distinctions

# %%
with open("data/code_penal.txt", "w", encoding="utf-8") as f:
    f.write(text)

# %%
# Rechargement
with open("data/code_penal.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
pattern = r'(Article\s+(?:\d+(?:er)?|premier))'

# %%
import re

articles = re.split(pattern, text)

# %%
article_chunks = []

for i in range(1, len(articles), 2):
    article_title = articles[i]
    article_content = articles[i+1]

    article_chunks.append(article_title + article_content)

# %%
# vérification
print(len(article_chunks))
print(article_chunks[0])
# Out:
# 1205
# Article premier : Les infractions pénales sont classées, suivant leur gravité, en crimes, délits
# et contraventions.
# 1) les crimes sont punis de peines criminelles;
# 2) les délits sont punis de peines correctionnelles;
# 3) les contraventions sont punies de peines de police.

# %%
import json

with open("data/articles.json", "w", encoding="utf-8") as f:
    json.dump(article_chunks, f, ensure_ascii=False, indent=2)

# %%
pip install sentence-transformers faiss-cpu
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (0.27.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: numpy in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (1.26.4)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (4.11.0)
# Requirement already satisfied: tqdm in c:\users\cleme\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: packaging in c:\users\cleme\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: filelock in c:\users\cleme\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\cleme\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\cleme\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\cleme\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in c:\users\cleme\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\cleme\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\cleme\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\cleme\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\cleme\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\cleme\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\cleme\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\cleme\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\cleme\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Collecting joblib>=1.3.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\cleme\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cleme\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cleme\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cleme\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cleme\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cleme\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Downloading sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Downloading faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    ------ --------------------------------- 3.1/18.9 MB 15.3 MB/s eta 0:00:02
#    ------------ --------------------------- 5.8/18.9 MB 14.1 MB/s eta 0:00:01
#    ------------------- -------------------- 9.2/18.9 MB 14.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 11.3/18.9 MB 14.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.4/18.9 MB 12.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 16.8/18.9 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------  18.6/18.9 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 11.9 MB/s eta 0:00:00
# Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Installing collected packages: joblib, faiss-cpu, scikit-learn, sentence-transformers
# Successfully installed faiss-cpu-1.13.2 joblib-1.5.3 scikit-learn-1.8.0 sentence-transformers-5.3.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dython 0.7.9 requires pandas>=1.4.2, which is not installed.
# fairlearn 0.12.0 requires pandas>=2.0.3, which is not installed.
# prince 0.14.0 requires pandas<3.0.0,>=2.2.0, which is not installed.
# shap 0.47.1 requires pandas, which is not installed.

# %%
import json

with open("data/articles.json", "r", encoding="utf-8") as f:
    articles = json.load(f)

print(len(articles))
print(articles[0])
# Out:
# 1205
# Article premier : Les infractions pénales sont classées, suivant leur gravité, en crimes, délits
# et contraventions.
# 1) les crimes sont punis de peines criminelles;
# 2) les délits sont punis de peines correctionnelles;
# 3) les contraventions sont punies de peines de police.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\cleme\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cleme\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\cleme\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\cleme\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-3.0.1-cp312-cp312-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.7 MB 14.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.7 MB 10.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.7 MB 10.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.7 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-3.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# prince 0.14.0 requires pandas<3.0.0,>=2.2.0, but you have pandas 3.0.1 which is incompatible.
# streamlit 1.37.1 requires pandas<3,>=1.3.0, but you have pandas 3.0.1 which is incompatible.

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = model.encode(articles, show_progress_bar=True)
# Out:
# C:\Users\cleme\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\cleme\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
# WARNING:tensorflow:From C:\Users\cleme\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\cleme\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:140: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\cleme\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/38 [00:00<?, ?it/s]

# %%
import faiss
import numpy as np

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(np.array(embeddings))

# %%
print(index.ntotal)
# Out:
# 1205

# %%
import os

os.makedirs("vector_db", exist_ok=True)

# %%
faiss.write_index(index, "vector_db/code_penal.index")

# %%
query = "injure publique"

query_embedding = model.encode([query])

D, I = index.search(query_embedding, k=5)

for i in I[0]:
    print(articles[i])
    print("\n-----------------\n")
# Out:
# Article 58 1 : Tout agent de la force publique préposé à la garde d’un détenu qui par sa
# négligence favorise l’évasion de ce détenu est puni d’une peine d’emprisonnement d'un (01) à
# six (06) mois.
#
#
# -----------------
#
# Article 845 : Toute autre infraction aux dispositions du code de la santé publique relatives
# aux mesures d'h ygiène, dûment constatée par un procès -verbal de vérification établi par les
# agents d'hygiène publique en collaboration avec les services techniques compétents, est punie
# d'une amende de cent mille (100.000) à cinq cent mille (500.000) de francs CFA sans
# préjudice de l'application d'autres dispositions du présent code.
# Section 2 : Des infractions relatives à la prévention des épidémies165
#
#
# -----------------
#
# Article 501 : Constitue un refus d’obtempérer, l’inobservation délibérée d’un ordre légitime
# donné sur la voie publique ou dans un lieu public par un représentant de l’autorité publique,
# agissant dans l’exercice de ses fonctions.
#
#
# -----------------
#
# Article 492 : La peine d’amende prévue à l’article précédent peut être portée au double si
# l’injure ou l’outrage a été proféré publiquement ou a fait l’objet d’une diffusion publique du
# fait de son auteur.93
# Lorsque l’outrage au drapeau ou à l’hymne national est commis en réunion, la peine encourue
# est d’un (01) à six (06) mois d’emprisonnement et l’amende de cinq cent (500 000) à deux
# millions (2.000.000) de francs CFA.
# Paragraphe 2 : Des menaces et violences envers des représentants de  l’autorité publique
#
#
# -----------------
#
# Article 390 : Constitue un outrage public à la pudeur l’exhibition sexuelle consistant à causer
# publiquement scandale par des scènes ou des gestes obscènes.
#
#
# -----------------

# %%
def retrieve_articles(query, k=5):

    query_embedding = model.encode([query])

    D, I = index.search(query_embedding, k)

    results = [articles[i] for i in I[0]]

    return results

# %%
retrieve_articles("insulte publique")
# Out:
# ['Article 501 : Constitue un refus d’obtempérer, l’inobservation délibérée d’un ordre légitime \ndonné sur la voie publique ou dans un lieu public par un représentant de l’autorité publique, \nagissant dans l’exercice de ses fonctions.\n',
#  'Article 390 : Constitue un outrage public à la pudeur l’exhibition sexuelle consistant à causer \npubliquement scandale par des scènes ou des gestes obscènes.\n',
#  'Article 492 : La peine d’amende prévue à l’article précédent peut être portée au double si \nl’injure ou l’outrage a été proféré publiquement ou a fait l’objet d’une diffusion publique du \nfait de son auteur.93\nLorsque l’outrage au drapeau ou à l’hymne national est commis en réunion, la peine encourue \nest d’un (01) à six (06) mois d’emprisonnement et l’amende de cinq cent (500 000) à deux \nmillions (2.000.000) de francs CFA.\nParagraphe 2 : Des menaces et violences envers des représentants de  l’autorité publique\n',
#  "Article 1198 : L'action publique intentée en vertu de la présente section, se prescrit par six \n(06) mois à compter du quinzième (15ème) jour suivant le vote.\n",
#  "Article 58 1 : Tout agent de la force publique préposé à la garde d’un détenu qui par sa \nnégligence favorise l’évasion de ce détenu est puni d’une peine d’emprisonnement d'un (01) à \nsix (06) mois.\n"]

# %%
def build_context(docs):

    context = "\n\n".join(docs)

    return context

# %%
def build_prompt(question, context):

    prompt = f"""
Tu es un assistant juridique spécialisé dans le droit togolais.

Réponds uniquement à partir des articles fournis.

Articles :
{context}

Question :
{question}

Réponse :
"""
    return prompt

# %%
import requests

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "llama3",
        "prompt": "Explique le vol en droit pénal",
        "stream": False
    }
)

print(response.json()["response"])
# Out:
# Le vol, également connu sous le nom de délit de vol, est un délit pénal qui consiste à prendre, à prendre ou à posséder, sans le consentement du propriétaire, des biens appartenant à autrui. Voici une explication détaillée du vol en droit pénal :
#
# **Définition**
#
# Le vol est défini comme l'acte de prendre, de prendre ou de posséder, sans le consentement du propriétaire, des biens appartenant à autrui. Ce délit peut concerner des biens meubles (objets, argent, etc.) ou immeubles (biens fonciers, etc.).
#
# **Elements du délit**
#
# Pour qu'un vol soit considéré comme un délit, il doit présenter les éléments suivants :
#
# 1. **L'acte de prendre, de prendre ou de posséder** : il s'agit de l'action de prendre ou de posséder un bien appartenant à autrui.
# 2. **Sans le consentement du propriétaire** : le propriétaire doit avoir refusé son consentement ou ne pas être d'accord pour que l'acte de prendre ou de posséder soit considéré comme illicite.
# 3. **Un bien appartenant à autrui** : le bien doit appartenir à une personne autre que l'auteur du délit.
#
# **Formes du vol**
#
# Il existe différentes formes de vol, qui sont définies par les législations nationales :
#
# * **Vol simple** : il s'agit du vol de biens meubles ou immeubles.
# * **Vol qualifié** : il s'agit du vol de biens meubles ou immeubles, qui a été commis avec violence, effraction ou usage de menaces.
# * **Vol d'agréments** : il s'agit du vol de biens intangibles, tels que des sommes d'argent, des effets de commerce, etc.
#
# **Poursuites et peines**
#
# En cas de délit de vol, les poursuites et les peines varient en fonction de la législation nationale et des circonstances du délit. Les peines peuvent inclure :
#
# * **Avertissement** : un avertissement verbal ou écrit pour signaler la gravité du délit.
# * **Amende** : une pénalité financière pour la personne responsable du délit.
# * **Perte de liberté** : une peine de prison, qui peut varier en fonction de la gravité du délit et de l'antériorité de la personne responsable.
#
# Il est important de noter que le vol est un délit qui est puni en droit pénal, mais il est également possible de se faire poursuivre pour des faits de vol dans le cadre d'un litige civil, si le propriétaire du bien affecté par le vol demande des dommages-intérêts.

# %%
def rag_pipeline(question):

    query_embedding = model.encode([question])

    D, I = index.search(query_embedding, k=5)

    docs = [articles[i] for i in I[0]]

    context = "\n\n".join(docs)

    prompt = f"""
Tu es un assistant juridique spécialisé dans le droit togolais.

Réponds uniquement à partir des articles suivants.

Articles :
{context}

Question :
{question}

Réponse :
"""

    response = requests.post(
        "http://localhost:11434/api/generate",
        json={
            "model": "llama3",
            "prompt": prompt,
            "stream": False
        }
    )

    return response.json()["response"]

# %%
rag_pipeline("Si quelqu'un insulte une personne en public que risque-t-il ?")
# Out:
# "Selon les articles du code pénal togolais, si quelqu'un insulte une personne en public, il risque d'être puni d'une amende de cent mille (100.000) à cinq cent mille (500.000) francs CFA, conformément à l'article 298. Si l'injure comporte un terme de mépris tenant au sexe, au genre, au handicap, à l'appartenance raciale, ethnique, religieuse ou nationale, à la séropositivité au VIH de la victime, l'auteur est puni d'une peine d'emprisonnement d'un (01) à six (06) mois et l'amende peut être portée au double."
